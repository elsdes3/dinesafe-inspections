# %% [markdown]
# # Transforming Infractions into Inspections

# %%
# %load_ext lab_black

# %%
import configparser
from datetime import datetime

import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
# Access `../sql.ini` (database connection details) as environment variables
config = configparser.ConfigParser()
config.read("../sql.ini")
default_cfg = config["default"]

# %%
DB_TYPE = default_cfg["DB_TYPE"]
DB_DRIVER = default_cfg["DB_DRIVER"]
DB_USER = default_cfg["DB_USER"]
DB_PASS = default_cfg["DB_PASS"]
DB_HOST = default_cfg["DB_HOST"]
DB_PORT = default_cfg["DB_PORT"]
DB_NAME = default_cfg["DB_NAME"]

# %%
# Connect to all databases (required to perform CRUD operations and submit queries)
URI = f"{DB_TYPE}+{DB_DRIVER}://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# %% [markdown]
# ## Background

# %% [markdown]
# The following are facts about the data based on the city of Toronto's [Open Data Portal page for DineSafe data](https://open.toronto.ca/dataset/dinesafe/) and [general info page for the DineSafe program](https://www.toronto.ca/community-people/health-wellness-care/health-programs-advice/food-safety/dinesafe/about-dinesafe/)
# 1. A single inspection takes place on a specific date at a single establishment. An `inspection_id` should be unique for each inspection. An `establishment_id` should be unique for each establishment.
# 2. A group of establishments, in a chain (such as the [SUBWAY](https://en.wikipedia.org/wiki/Subway_(restaurant)) brand), can have multiple locations.
# 3. Each location can be inspected one or more times (usually more than once). So, a single `establishment_id` and `inspection_id` should be associated with a single `inspection_date`.
# 4. One or more infractions can be recorded per inspection. In the data, each infraction is listed on a single row. There can be multiple rows (of infractions) per inspection.
# 5. If a Significant infraction is detected, an [inspector returns within two days](https://www.toronto.ca/community-people/health-wellness-care/health-programs-advice/food-safety/dinesafe/dinesafe-infractions/) to re-inspect (follow-up inspection) the establishment.

# %% [markdown]
# ### Implications for Current Use-Case

# %% [markdown]
# For the current ML use-case, we require each *observation* to be an independent inspection with an infraction (crucial, significant or minor). We will then create a binary variable indicating whether the inspection resulted in a crucial infraction (1) or not (0) since that is that label that the ML algorithm needs to predict. The ML model will not be predicting the outcome of follow-up inspections, but will only be trained to predict the outcome (if there was a crucial infraction or not) of the initial inspection. Also, since there is no use in predicting the outcome of inspections that do not result in an infraction (crucial or not), the ML algorithm will not need access to data about such inpsections.
#
# When exploring the data, we will need to take these considerations into account as well as the facts about the data mentioned above.

# %% [markdown]
# ## Connect to the MySQL Database

# %% [markdown]
# Create a SQLAlchemy engine object and get a connection to the `dinesafe` database on the MySQL server

# %%
engine = create_engine(URI)
conn = engine.connect()

# %% [markdown]
# ## Preliminary Exploration of Data

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT *
    FROM inspections
    LIMIT 6
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 4.4 ms, sys: 404 µs, total: 4.8 ms
# Wall time: 4.21 ms
#    row_id  establishment_id  inspection_id            establishment_name  \
# 0       1           1222579      102810896  SAI-LILA KHAMAN DHOKLA HOUSE
# 1       2           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 2       3           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 3       4           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 4       5           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 5       6           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
#
#   establishmenttype establishment_address latitude longitude  \
# 0     Food Take Out        870 MARKHAM RD     None      None
# 1     Food Take Out        870 MARKHAM RD     None      None
# 2     Food Take Out        870 MARKHAM RD     None      None
# 3     Food Take Out        870 MARKHAM RD     None      None
# 4     Food Take Out        870 MARKHAM RD     None      None
# 5     Food Take Out        870 MARKHAM RD     None      None
#
#   establishment_status  minimum_inspections_peryear  \
# 0                 Pass                            2
# 1     Conditional Pass                            2
# 2     Conditional Pass                            2
# 3     Conditional Pass                            2
# 4     Conditional Pass                            2
# 5     Conditional Pass                            2
#
#                                   infraction_details inspection_date  \
# 0                                               None      2012-08-21
# 1  FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...      2013-06-26
# 2                 Food handler fail to wear headgear      2013-06-26
# 3  Operator fail to ensure food is not contaminat...      2013-06-26
# 4  Operator fail to maintain hazardous food(s) at...      2013-06-26
# 5           Operator fail to properly maintain rooms      2013-06-26
#
#           severity                       action court_outcome amount_fined
# 0             None                         None          None         None
# 1  S - Significant  Corrected During Inspection          None         None
# 2        M - Minor             Notice to Comply          None         None
# 3      C - Crucial             Notice to Comply          None         None
# 4      C - Crucial             Notice to Comply          None         None
# 5        M - Minor             Notice to Comply          None         None

# %% [markdown]
# ### Count number of establishments per Inspection

# %% [markdown]
# Count the number of establishments per inspection (we should have, at most, one restaurant for each inspection ID) and sort the results in descending order of the number of establishments

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT inspection_id,
           COUNT(DISTINCT(establishment_id)) AS num_establishments
    FROM inspections
    GROUP BY inspection_id
    ORDER BY COUNT(DISTINCT(inspection_id)) DESC
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 1.34 s, sys: 57.8 ms, total: 1.4 s
# Wall time: 2.19 s
#         inspection_id  num_establishments
# 0           104571930                   1
# 1           104571931                   1
# 2           104571932                   1
# 3           104571939                   1
# 4           104571970                   1
# ...               ...                 ...
# 246629      103934110                   1
# 246630      103934112                   1
# 246631      103934121                   1
# 246632      103934148                   1
# 246633      103934154                   1
#
# [246634 rows x 2 columns]

# %% [markdown]
# As expected, we only have one establishment recorded per inspection ID.

# %% [markdown]
# ### Count number of Inspections per Establishment

# %% [markdown]
# Count the number of inspections per establishment (we should have one or more inspections per establishment)

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT establishment_id,
           establishmenttype,
           establishment_address,
           COUNT(DISTINCT(inspection_id)) AS num_inspections
    FROM inspections
    GROUP BY establishment_id, establishmenttype, establishment_address
    ORDER BY COUNT(DISTINCT(inspection_id)) DESC
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 185 ms, sys: 11.8 ms, total: 196 ms
# Wall time: 1.64 s
#        establishment_id                   establishmenttype  \
# 0              10336522                         Supermarket
# 1              10282501                              Bakery
# 2              10399527                       Food Take Out
# 3               9011824                          Restaurant
# 4              10420908                          Restaurant
# ...                 ...                                 ...
# 30285          10690642                           Bake Shop
# 30286          10690660                          Restaurant
# 30287          10690679                       Food Take Out
# 30288          10690680  Food Store (Convenience / Variety)
# 30289          10690681                          Restaurant
#
#         establishment_address  num_inspections
# 0         4466 SHEPPARD AVE E               60
# 1         2300 LAWRENCE AVE E               51
# 2         4810 SHEPPARD AVE E               48
# 3         4386 SHEPPARD AVE E               48
# 4      3601 VICTORIA PARK AVE               47
# ...                       ...              ...
# 30285        20 ST PATRICK ST                1
# 30286          549 BLOOR ST W                1
# 30287     1175 ST CLAIR AVE W                1
# 30288     155 WELLINGTON ST W                1
# 30289     200 QUEENS PLATE DR                1
#
# [30290 rows x 4 columns]

# %% [markdown]
# We do have one or more inspections per establishment inspected. Since an establishment can be inspected multiple times, this is expected.

# %% [markdown]
# ### Count number of infractions per inspection

# %% [markdown]
# To do this, it only makes sense to count the number of infractions per inspection per establishment

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT establishment_id,
           establishmenttype,
           establishment_address,
           inspection_id,
           COUNT(*) AS number_of_infractions
    FROM inspections
    GROUP BY establishment_id, establishmenttype, establishment_address, inspection_id
    ORDER BY COUNT(*) DESC
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 1.97 s, sys: 70 ms, total: 2.04 s
# Wall time: 3.76 s
#         establishment_id      establishmenttype establishment_address  \
# 0               10356286             Restaurant      4016 FINCH AVE E
# 1               10528444  Food Processing Plant       19 WATERMAN AVE
# 2                9031081          Food Take Out   200 WELLINGTON ST W
# 3               10191833             Restaurant         5594 YONGE ST
# 4               10522734             Restaurant     1686 ELLESMERE RD
# ...                  ...                    ...                   ...
# 247323           9408154      Food Court Vendor         6312 YONGE ST
# 247324           9408154      Food Court Vendor         6312 YONGE ST
# 247325           9408426           Food Caterer     195 BENTWORTH AVE
# 247326           9408426           Food Caterer     195 BENTWORTH AVE
# 247327           9408426           Food Caterer     195 BENTWORTH AVE
#
#         inspection_id  number_of_infractions
# 0           103465643                     90
# 1           103473708                     84
# 2           103580745                     84
# 3           103598378                     80
# 4           103428956                     80
# ...               ...                    ...
# 247323      102908755                      1
# 247324      102982172                      1
# 247325      102709799                      1
# 247326      102764842                      1
# 247327      102842602                      1
#
# [247328 rows x 5 columns]

# %% [markdown]
# As we can see, there can be one or more infractions per inspection performed at a given establishment.

# %% [markdown]
# The first inspection found above did indeed detect 90 infractions as shown below

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT *
    FROM inspections
    WHERE inspection_id = 103465643
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 20.2 ms, sys: 652 µs, total: 20.8 ms
# Wall time: 625 ms
#     row_id  establishment_id  inspection_id       establishment_name  \
# 0    51235          10356286      103465643  MILLIKEN BAR RESTAURANT
# 1    51236          10356286      103465643  MILLIKEN BAR RESTAURANT
# 2    51237          10356286      103465643  MILLIKEN BAR RESTAURANT
# 3    51238          10356286      103465643  MILLIKEN BAR RESTAURANT
# 4    51239          10356286      103465643  MILLIKEN BAR RESTAURANT
# ..     ...               ...            ...                      ...
# 85   35175          10356286      103465643  MILLIKEN BAR RESTAURANT
# 86   35176          10356286      103465643  MILLIKEN BAR RESTAURANT
# 87   35177          10356286      103465643  MILLIKEN BAR RESTAURANT
# 88   35178          10356286      103465643  MILLIKEN BAR RESTAURANT
# 89   35179          10356286      103465643  MILLIKEN BAR RESTAURANT
#
#    establishmenttype establishment_address latitude longitude  \
# 0         Restaurant      4016 FINCH AVE E     None      None
# 1         Restaurant      4016 FINCH AVE E     None      None
# 2         Restaurant      4016 FINCH AVE E     None      None
# 3         Restaurant      4016 FINCH AVE E     None      None
# 4         Restaurant      4016 FINCH AVE E     None      None
# ..               ...                   ...      ...       ...
# 85        Restaurant      4016 FINCH AVE E     None      None
# 86        Restaurant      4016 FINCH AVE E     None      None
# 87        Restaurant      4016 FINCH AVE E     None      None
# 88        Restaurant      4016 FINCH AVE E     None      None
# 89        Restaurant      4016 FINCH AVE E     None      None
#
#    establishment_status  minimum_inspections_peryear  \
# 0      Conditional Pass                            3
# 1      Conditional Pass                            3
# 2      Conditional Pass                            3
# 3      Conditional Pass                            3
# 4      Conditional Pass                            3
# ..                  ...                          ...
# 85     Conditional Pass                            3
# 86     Conditional Pass                            3
# 87     Conditional Pass                            3
# 88     Conditional Pass                            3
# 89     Conditional Pass                            3
#
#                                    infraction_details inspection_date  \
# 0            Operator fail to clean washroom fixtures      2015-04-15
# 1   Operator fail to ensure food is not contaminat...      2015-04-15
# 2   Operator fail to maintain hazardous foods at 6...      2015-04-15
# 3        Operator fail to properly maintain equipment      2015-04-15
# 4   Operator fail to properly maintain equipment(N...      2015-04-15
# ..                                                ...             ...
# 85     Operator fail to provide hand washing supplies      2015-04-15
# 86          Operator fail to provide proper equipment      2015-04-15
# 87  Operator fail to provide proper garbage contai...      2015-04-15
# 88  Operator fail to use proper procedure(s) to en...      2015-04-15
# 89  Operator fail to use proper utensils to ensure...      2015-04-15
#
#            severity            action court_outcome amount_fined
# 0   S - Significant  Notice to Comply          None         None
# 1       C - Crucial  Notice to Comply          None         None
# 2       C - Crucial  Notice to Comply          None         None
# 3   S - Significant  Notice to Comply          None         None
# 4         M - Minor  Notice to Comply          None         None
# ..              ...               ...           ...          ...
# 85  S - Significant  Notice to Comply          None         None
# 86        M - Minor  Notice to Comply          None         None
# 87        M - Minor  Notice to Comply          None         None
# 88  S - Significant  Notice to Comply          None         None
# 89  S - Significant  Notice to Comply          None         None
#
# [90 rows x 16 columns]

# %% [markdown]
# ### Get Data with a Missing Address

# %%
# %%time
df_miss_address = pd.read_sql(
    """
    SELECT COUNT(*) AS num_missing_addresses
    FROM inspections
    WHERE establishment_address IS NULL
    """,
    con=conn,
)
df_miss_address.head()
# Out:
# CPU times: user 77 µs, sys: 2.59 ms, total: 2.67 ms
# Wall time: 392 ms
#    num_missing_addresses
# 0                      0

# %% [markdown]
# There are no inspections where the establishment address is missing.

# %% [markdown]
# ### Get Data with a Missing Latitude or Longitude

# %% [markdown]
# Get all inspections missing either a latitude or longitude
# - in the next notebook, we will geocode these locations so that we can (later) determine the neighbourhood for each establishment and get supplementary datasets that provide metadata for each neighbourhood

# %%
# %%time
df_miss_lat_lon = pd.read_sql(
    """
    SELECT *
    FROM inspections
    WHERE latitude IS NULL
    OR longitude IS NULL
    """,
    con=conn,
)
df_miss_lat_lon.head()
# Out:
# CPU times: user 11.3 s, sys: 370 ms, total: 11.6 s
# Wall time: 11.6 s
#    row_id  establishment_id  inspection_id            establishment_name  \
# 0       1           1222579      102810896  SAI-LILA KHAMAN DHOKLA HOUSE
# 1       2           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 2       3           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 3       4           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
# 4       5           1222579      103015258  SAI-LILA KHAMAN DHOKLA HOUSE
#
#   establishmenttype establishment_address latitude longitude  \
# 0     Food Take Out        870 MARKHAM RD     None      None
# 1     Food Take Out        870 MARKHAM RD     None      None
# 2     Food Take Out        870 MARKHAM RD     None      None
# 3     Food Take Out        870 MARKHAM RD     None      None
# 4     Food Take Out        870 MARKHAM RD     None      None
#
#   establishment_status  minimum_inspections_peryear  \
# 0                 Pass                            2
# 1     Conditional Pass                            2
# 2     Conditional Pass                            2
# 3     Conditional Pass                            2
# 4     Conditional Pass                            2
#
#                                   infraction_details inspection_date  \
# 0                                               None      2012-08-21
# 1  FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...      2013-06-26
# 2                 Food handler fail to wear headgear      2013-06-26
# 3  Operator fail to ensure food is not contaminat...      2013-06-26
# 4  Operator fail to maintain hazardous food(s) at...      2013-06-26
#
#           severity                       action court_outcome  amount_fined
# 0             None                         None          None           NaN
# 1  S - Significant  Corrected During Inspection          None           NaN
# 2        M - Minor             Notice to Comply          None           NaN
# 3      C - Crucial             Notice to Comply          None           NaN
# 4      C - Crucial             Notice to Comply          None           NaN

# %% [markdown]
# There are many rows with missing values in the `latitude` or `longitude` columns for the same address. As seen earlier, there could be many infractions recorded in this dataset for a single establishment (address) on a given date.

# %% [markdown]
# For geocoding purposes, we only need to get each (unique) address (with missing latitude or longitude) once. We'll now write a SQL query to give this output

# %%
# %%time
df_addr_lat_lon = pd.read_sql(
    """
    SELECT establishment_address,
           MAX(latitude) AS latitude,
           MAX(longitude) AS longitude
    FROM inspections
    WHERE latitude IS NULL
    OR longitude IS NULL
    GROUP BY establishment_address
    """,
    con=conn,
)
df_addr_lat_lon
# Out:
# CPU times: user 135 ms, sys: 7.93 ms, total: 143 ms
# Wall time: 1.04 s
#       establishment_address latitude longitude
# 0            870 MARKHAM RD     None      None
# 1              1550 JANE ST     None      None
# 2       1635 LAWRENCE AVE W     None      None
# 3           606 BROWNS LINE     None      None
# 4          500 REXDALE BLVD     None      None
# ...                     ...      ...       ...
# 13280          8 SEASONS DR     None      None
# 13281     453 PARLIAMENT ST     None      None
# 13282       121 HUMBER BLVD     None      None
# 13283         5298 YONGE ST     None      None
# 13284          690 YONGE ST     None      None
#
# [13285 rows x 3 columns]

# %% [markdown]
# Check that every row in the above query has missing values in **both** the `latitude` and `longitude` columns. To do this, we'll count the number of
# - establishments
# - missing values in the `latitude` column
# - missing values in the `longitude` column
#
# If each establishment with a missing value in the `latitude` or `longitude` column is **also** missing a value in the `longitude` or `latitude` column, then we will know that every establishment listed in the above query is missing values in **both** the `latitude` and `longitude` columns

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT SUM(CASE WHEN latitude IS NULL THEN 1 ELSE 0 END) AS num_miss_lat,
           SUM(CASE WHEN longitude IS NULL THEN 1 ELSE 0 END) AS num_miss_lon,
           COUNT(DISTINCT(establishment_address)) AS num_establishments
    FROM (
        SELECT establishment_address,
               MAX(latitude) AS latitude,
               MAX(longitude) AS longitude
        FROM inspections
        WHERE latitude IS NULL
        OR longitude IS NULL
        GROUP BY establishment_address
    ) AS combo
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 2.83 ms, sys: 266 µs, total: 3.1 ms
# Wall time: 929 ms
#    num_miss_lat  num_miss_lon  num_establishments
# 0       13285.0       13285.0               13285

# %% [markdown]
# Since these row counts agree with eachother, we can say that every establishment with a missing value in the `latitude` column is also missing a value in the `longitude` column, and vice-versa.

# %% [markdown]
# ### Types of Infraction Severities

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT severity,
           COUNT(*) AS num_infractions
    FROM inspections
    GROUP BY severity
    ORDER BY COUNT(*) DESC
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 3.34 ms, sys: 0 ns, total: 3.34 ms
# Wall time: 831 ms
#               severity  num_infractions
# 0                 None           359119
# 1            M - Minor           330971
# 2      S - Significant           223491
# 3  NA - Not Applicable            41503
# 4          C - Crucial            26715

# %% [markdown]
# **Observatoins**
# 1. Our model needs to be trained on infractions only. It will need to know whether an infraction is crucial or not (significant, minor), since this is what we are trying to predict (whether a crucial infraction is detected during an inspection or not). We are not trying to predict (ahead of time) if an inspection will produce no infractions. So, we don't need inspections with no infraction (where the severity is `NULL`).
# 2. We may also not need to keep inspections where the infraction severity is `NA - Not Applicable`, but we'll need to explore this first.

# %% [markdown]
# Show the infractions with a severity of `NA - ...`

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT infraction_details,
           severity,
           establishment_status
    FROM inspections
    WHERE severity LIKE '%%NA -%%'
    """,
    con=conn,
)
with pd.option_context('display.max_colwidth',1000):
    display(df_query)
# Out:
#                                                                                                                  infraction_details  \
# 0      Fail to ensure the presence of the holder of a valid food handler's certificate  -  Municipal Code Chapter 545 Sec. G(17)(a)
# 1                                      Fail to hold a valid food handler's certificate -  Municipal Code Chapter 545 Sec. 5G(17)(b)
# 2      Fail to ensure the presence of the holder of a valid food handler's certificate  -  Municipal Code Chapter 545 Sec. G(17)(a)
# 3      Fail to ensure the presence of the holder of a valid food handler's certificate  -  Municipal Code Chapter 545 Sec. G(17)(a)
# 4      Fail to ensure the presence of the holder of a valid food handler's certificate  -  Municipal Code Chapter 545 Sec. G(17)(a)
# ...                                                                                                                             ...
# 41498                       Fail to Ensure the Presence of the Holder of a Valid Food Handlers Certificate - Sec. 545- 157E(1 7)(a)
# 41499                       Fail to Ensure the Presence of the Holder of a Valid Food Handlers Certificate - Sec. 545- 157E(1 7)(a)
# 41500                       Fail to Ensure the Presence of the Holder of a Valid Food Handlers Certificate - Sec. 545- 157E(1 7)(a)
# 41501                                           Fail to Post Licence Adjacent to Food Safety Inspection Notice - Sec. 545-157(E)(4)
# 41502                                                       Fail to Hold a Valid Food Handler's Certificate  - Sec. 545-157E(17)(b)
#
#                   severity establishment_status
# 0      NA - Not Applicable     Conditional Pass
# 1      NA - Not Applicable     Conditional Pass
# 2      NA - Not Applicable     Conditional Pass
# 3      NA - Not Applicable     Conditional Pass
# 4      NA - Not Applicable     Conditional Pass
# ...                    ...                  ...
# 41498  NA - Not Applicable     Conditional Pass
# 41499  NA - Not Applicable                 Pass
# 41500  NA - Not Applicable     Conditional Pass
# 41501  NA - Not Applicable                 Pass
# 41502  NA - Not Applicable                 Pass
#
# [41503 rows x 3 columns]
# CPU times: user 246 ms, sys: 466 µs, total: 246 ms
# Wall time: 565 ms

# %% [markdown]
# Show the assigned establishment status for infractions assigned a severity of `NA - ...`

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT establishment_status,
           COUNT(*) AS num_rows
    FROM inspections
    WHERE severity LIKE '%%NA -%%'
    GROUP BY establishment_status
    """,
    con=conn,
)
with pd.option_context('display.max_colwidth',1000):
    display(df_query)
# Out:
#   establishment_status  num_rows
# 0     Conditional Pass      9596
# 1               Closed       124
# 2                 Pass     31783
# CPU times: user 8.9 ms, sys: 125 µs, total: 9.03 ms
# Wall time: 541 ms

# %% [markdown]
# **Observations**
# 1. Nearly all these infractions result in a `Pass` being assigned to th establishment. However, the infraction details column does suggest that some infraction was detected by the inspector. Unfortunately, there is no valid entry (Crucial, Significant or Minor) in the `severity` column.
# 2. Could we map the `establishment_status` that is `Pass` or `Conditional Pass` to non-critical infractions and `Closed` to critical? If we can do this, then we would be justified in keeping these infractions (where severity is `NA - ...`); if not then we will have to drop them.

# %% [markdown]
# Show the infraction details for infractions with a severity of `NA - ...` that resulted in the establishment being `Closed`

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT infraction_details,
           severity,
           establishment_status
    FROM inspections
    WHERE severity LIKE '%%NA -%%'
    AND establishment_status = 'Closed'
    """,
    con=conn,
)
with pd.option_context('display.max_colwidth',1000):
    display(df_query)
# Out:
#                                                                                                                                                                                                     infraction_details  \
# 0    Fail to , upon request by any person, produce the food safety inspection report or reports relating to the currently posted food inspection notice for such establishment - Municipal Code Chapter 545 Sec. 5G(5)
# 1                                                                                         Fail to ensure the presence of the holder of a valid food handler's certificate  -  Municipal Code Chapter 545 Sec. G(17)(a)
# 2                                                                    Fail to post the eating and drinking establishment license adjacent to the food safety inspection notice -  Municipal Code Chapter 545 Sec. 5G(4)
# 3                                                                                                                         Fail to hold a valid food handler's certificate -  Municipal Code Chapter 545 Sec. 5G(17)(b)
# 4                                                                                         Fail to ensure the presence of the holder of a valid food handler's certificate  -  Municipal Code Chapter 545 Sec. G(17)(a)
# ..                                                                                                                                                                                                                 ...
# 119                                                                                              Fail to Ensure the Presence of the Holder of a Valid Food Handler's Certificate. Muncipal Code Chapter 545-157(17)(a)
# 120                                                                                                            Fail to Ensure the Presence of the Holder of a Valid Food Handlers Certificate - Sec. 545- 157E(1 7)(a)
# 121                                                                                                                                Fail to Post Licence Adjacent to Food Safety Inspection Notice - Sec. 545-157(E)(4)
# 122                                                                                                            Fail to Ensure the Presence of the Holder of a Valid Food Handlers Certificate - Sec. 545- 157E(1 7)(a)
# 123                                                                                                            Fail to Ensure the Presence of the Holder of a Valid Food Handlers Certificate - Sec. 545- 157E(1 7)(a)
#
#                 severity establishment_status
# 0    NA - Not Applicable               Closed
# 1    NA - Not Applicable               Closed
# 2    NA - Not Applicable               Closed
# 3    NA - Not Applicable               Closed
# 4    NA - Not Applicable               Closed
# ..                   ...                  ...
# 119  NA - Not Applicable               Closed
# 120  NA - Not Applicable               Closed
# 121  NA - Not Applicable               Closed
# 122  NA - Not Applicable               Closed
# 123  NA - Not Applicable               Closed
#
# [124 rows x 3 columns]
# CPU times: user 4.15 ms, sys: 3.28 ms, total: 7.43 ms
# Wall time: 477 ms

# %% [markdown]
# **Observations**
# 1. These seem like valid infractions that led to the establishment being closed. Unfortunately, we don't have a valid entry in the severity column. If the establishment was strong enough to lead to closing the establishment, then why did the inspector not assign a `Crucial` severity to the infraction? There seems to be some reasoning / judgement that was used in arriving at this conclusion but that reasoning is not present in the Dinesafe dataset. Our ML model will not be able to learn from such infractions. So, we'll exclude infractions with such a severity (`NA - ...`) from the data.

# %% [markdown]
# Below, we show the number of infractions by severity and the assigned establishment status

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT severity,
           establishment_status,
           COUNT(*) AS num_infractions
    FROM inspections
    GROUP BY severity, establishment_status
    ORDER BY COUNT(*) DESC
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 3.01 ms, sys: 0 ns, total: 3.01 ms
# Wall time: 1.13 s
#                severity establishment_status  num_infractions
# 0                  None                 Pass           359118
# 1             M - Minor                 Pass           270153
# 2       S - Significant                 Pass           125361
# 3       S - Significant     Conditional Pass            96556
# 4             M - Minor     Conditional Pass            59629
# 5   NA - Not Applicable                 Pass            31783
# 6           C - Crucial     Conditional Pass            25475
# 7   NA - Not Applicable     Conditional Pass             9596
# 8       S - Significant               Closed             1574
# 9           C - Crucial               Closed             1197
# 10            M - Minor               Closed             1189
# 11  NA - Not Applicable               Closed              124
# 12          C - Crucial                 Pass               43
# 13                 None     Conditional Pass                1

# %% [markdown]
# **Observations**
# 1. An establishment status of `Pass` or `Conditional Pass` could be associated with a crucial severity, not just minor, significant or `N/A- ...`. Similarly, `Closed` is associated with a minor and crucial establishment status. So, we cannot map `Pass` and `Conditional Pass` to non-crucical severity and `Closed` to crucial. This means we must drop infractions where the severity contains `NA - ...`.

# %% [markdown]
# ### Select from the Different Types of Establishments that were Inspected

# %% [markdown]
# The number of inspections and infractions (including non-infractions) is shown for each type of establishment below

# %%
# %%time
df_query = pd.read_sql(
    """
    SELECT establishmenttype,
           COUNT(DISTINCT(inspection_id)) AS num_inspections,
           COUNT(infraction_details) AS num_infractions
    FROM inspections
    WHERE severity NOT LIKE '%%NA -' AND severity IS NOT NULL
    GROUP BY establishmenttype
    ORDER BY COUNT(DISTINCT(inspection_id)) DESC
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 0 ns, sys: 2.96 ms, total: 2.96 ms
# Wall time: 1.19 s
#                            establishmenttype  num_inspections  num_infractions
# 0                                 Restaurant            55410           379246
# 1                              Food Take Out            13460            82247
# 2         Food Store (Convenience / Variety)             4009            22724
# 3                          Food Court Vendor             3622            22896
# 4                                Supermarket             3416            27161
# 5                                     Bakery             2621            20501
# 6                               Butcher Shop              971             6749
# 7              Child Care - Food Preparation              928             3875
# 8                       Child Care - Catered              919             3868
# 9                               Food Caterer              864             5435
# 10                     Food Processing Plant              854             6939
# 11                          Banquet Facility              809             4927
# 12                Retirement Homes(Licensed)              581             3301
# 13                 Cafeteria - Public Access              545             3238
# 14                                 Cafeteria              484             1695
# 15          Nursing Home / Home for the Aged              466             2586
# 16                Institutional Food Service              466             2431
# 17            Community Kitchen Meal Program              450             2402
# 18              Cocktail Bar / Beverage Room              416             2350
# 19         Boarding / Lodging Home - Kitchen              382             1960
# 20                School Nourishment Program              312             1838
# 21            Secondary School Food Services              271             1497
# 22                                Commissary              234             1369
# 23                                Food Depot              231             1413
# 24                           Serving Kitchen              229             1153
# 25                              Private Club              224              780
# 26                                 Bake Shop              213             1289
# 27                                 Fish Shop              177              978
# 28                Ice Cream / Yogurt Vendors              161              919
# 29             Hospitals & Health Facilities              138              634
# 30            Refreshment Stand (Stationary)               98              646
# 31                              Hot Dog Cart               92              470
# 32          Mobile Food Preparation Premises               87              421
# 33          College/University Food services               87              503
# 34           Elementary School Food services               71              434
# 35                                 Food Bank               61              236
# 36                               Flea Market               46              333
# 37                    Chartered Cruise Boats               38              274
# 38                   Church Banquet Facility               35              152
# 39                     Meat Processing Plant               29              219
# 40  Other Educational Facility Food Services               21              113
# 41                                 Rest Home               17               98
# 42             Retirement Homes(Un-licensed)               16               86
# 43                 Brew Your Own Beer / Wine               10               41
# 44                                 Food Cart                9               25
# 45     Fairs / Festivals / Special Occasions                9               43
# 46                            Bottling Plant                8               64
# 47                     Food Vending Facility                7               47
# 48                             Bowling Alley                6               22
# 49                          Catering Vehicle                4               16
# 50                           Bed & Breakfast                3                7
# 51                           Farmer's Market                3               16
# 52                           Ice Cream Plant                2                3
# 53                     Food Recovery Program                2                3
# 54                 Milk Pasteurization Plant                1                3
# 55                              Cheese Plant                1                3
# 56                                   Cannery                1                1

# %% [markdown]
# We will keep the following establishment types since they are equivalent to a restaurant or grocery store

# %%
establishment_types_wanted = [
    "Restaurant",
    "Food Take Out",
    "Food Store (Convenience / Variety)",  # equivalent to grocery store
    "Food Court Vendor",
    "Supermarket",  # equivalent to grocery store
    "Bakery",  # equivalent to grocery store
    # "Food Caterer",
    "Butcher Shop",  # equivalent to grocery store
    "Cafeteria - Public Access",
    # "Boarding / Lodging Home - Kitchen",
    "Cocktail Bar / Beverage Room",
    # "Food Depot",
    # "Private Club",
    "Fish Shop",  # equivalent to grocery store
    "Bake Shop",  # equivalent to grocery store
    # "Food Bank",
    "Flea Market",  # equivalent to grocery store
    "Farmer\\'s Market",  # equivalent to grocery store
    # "Bed & Breakfast",
]

# %% [markdown]
# The following is a string of all these wanted establishment types joined together, so that it can be used as a SQL filter (in the `WHERE` clause)

# %%
establishment_types_wanted_str = "('" + "', '".join(establishment_types_wanted) + "')"
print(establishment_types_wanted_str)
# Out:
# ('Restaurant', 'Food Take Out', 'Food Store (Convenience / Variety)', 'Food Court Vendor', 'Supermarket', 'Bakery', 'Butcher Shop', 'Cafeteria - Public Access', 'Cocktail Bar / Beverage Room', 'Fish Shop', 'Bake Shop', 'Flea Market', 'Farmer\'s Market')

# %% [markdown]
# **Observations**
# 1. The following are a subset of the non-retail food establishments that were inspected
#    - private / non-public
#      - boarding / lodging home - kitchen
#      - Private Club
#      - Bed & Breakfast
#    - niche (similar to school cafeteria)
#      - food depot
#      - food bank
#
#    and these are distinct from restaurants and grocery stores, so they are excluded from analysis here.
# 2. Schools, private establishment (private club, etc.) and Hospitals do not present a risk that can be generalized across the population of the city like restaurants and grocery stores. Also, these two types of establishments follow a different inspection and planning protocol.

# %% [markdown]
# ## Removing Invalid Data

# %% [markdown]
# ### Aggregate Data to get one inspection per row

# %% [markdown]
# Count the number of each type of infraction recorded during a single inspection. Also, combine all the (text) details of each infraction (`infraction_details`) into an `infractions_summary` column.

# %%
# %%time
df_query = pd.read_sql(
    f"""
    SELECT establishment_id,
           establishmenttype,
           establishment_address,
           inspection_date,
           inspection_id,
           GROUP_CONCAT(infraction_details SEPARATOR '. ') AS infractions_summary,
           CAST(SUM(CASE WHEN severity LIKE "%%S - Significant" THEN 1 ELSE 0 END) AS SIGNED) AS num_significant,
           CAST(SUM(CASE WHEN severity LIKE "%%C - Crucial" THEN 1 ELSE 0 END) AS SIGNED) AS num_crucial,
           CAST(SUM(CASE WHEN severity LIKE "%%M - Minor" THEN 1 ELSE 0 END) AS SIGNED) AS num_minor,
           COUNT(infraction_details) AS num_infractions
    FROM inspections
    WHERE establishmenttype IN {establishment_types_wanted_str}
    AND severity NOT LIKE '%%NA -' AND severity IS NOT NULL
    GROUP BY establishment_id, establishmenttype, establishment_address, inspection_date, inspection_id
    ORDER BY establishment_id, establishmenttype, establishment_address, inspection_date, inspection_id
    """,
    con=conn,
)
df_query
# Out:
# CPU times: user 1.18 s, sys: 19.8 ms, total: 1.2 s
# Wall time: 2.61 s
#        establishment_id establishmenttype   establishment_address  \
# 0               1222579     Food Take Out          870 MARKHAM RD
# 1               1222579     Food Take Out          870 MARKHAM RD
# 2               1222579     Food Take Out          870 MARKHAM RD
# 3               1222579     Food Take Out          870 MARKHAM RD
# 4               1222579     Food Take Out          870 MARKHAM RD
# ...                 ...               ...                     ...
# 85045          10690581        Restaurant  3560 VICTORIA PARK AVE
# 85046          10690642         Bake Shop        20 ST PATRICK ST
# 85047          10690660        Restaurant          549 BLOOR ST W
# 85048          10690679     Food Take Out     1175 ST CLAIR AVE W
# 85049          10690681        Restaurant     200 QUEENS PLATE DR
#
#       inspection_date  inspection_id  \
# 0          2013-06-26      103015258
# 1          2013-12-20      103133558
# 2          2014-09-09      103329697
# 3          2015-01-08      103420091
# 4          2016-12-21      103868579
# ...               ...            ...
# 85045      2019-10-22      104594294
# 85046      2019-10-23      104594681
# 85047      2019-10-23      104594800
# 85048      2019-10-23      104594954
# 85049      2019-10-23      104594980
#
#                                      infractions_summary  num_significant  \
# 0      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                4
# 1      Food handler fail to wear headgear. Operator f...                0
# 2      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                3
# 3      Operator fail to properly wash equipment. Oper...                3
# 4               Operator fail to properly wash equipment                0
# ...                                                  ...              ...
# 85045  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 85046  FAIL TO PROVIDE THERMOMETER IN REFRIGERATION E...                1
# 85047  FAIL TO MAINTAIN HANDWASHING STATIONS (LIQUID ...                1
# 85048  SANITIZE UTENSILS IN WATER FOR LESS THAN 45 SE...                1
# 85049  Fail to Hold a Valid Food Handler's Certificat...                0
#
#        num_crucial  num_minor  num_infractions
# 0                4          8               16
# 1                0          6                6
# 2                0         12               15
# 3                0          6                9
# 4                0          1                1
# ...            ...        ...              ...
# 85045            0          3                3
# 85046            0          0                1
# 85047            0          1                2
# 85048            0          0                1
# 85049            0          0                1
#
# [85050 rows x 10 columns]

# %% [markdown]
# **Notes**
# 1. We are excluding unwanted establishments and infractions where the severity is not valid. We discussed both of these choices earlier in the **Select from the Different Types of Establishments that were Inspected** and **Types of Infraction Severities** sub-sections respectively.

# %% [markdown]
# ### Remove Inspections that took more than one day to complete

# %% [markdown]
# A single inspection should be completed on one day. It should not be spread out over more than one day. From the above aggregated result, get inspections (`inspection_id`s) that took more than one day to complete
# - group by establishment and `inspection_id` and count the number of unique dates

# %%
df_query.groupby(
    ["establishment_id", "establishmenttype", "establishment_address", "inspection_id"],
    as_index=False,
)["inspection_date"].nunique().query("inspection_date > 1").sort_values(
    by=["inspection_date"], ascending=False
)
# Out:
#        establishment_id                   establishmenttype  \
# 6763            9011956                          Restaurant
# 12026           9043539                          Restaurant
# 19909          10223866                              Bakery
# 24622          10287338                          Restaurant
# 49525          10451955                       Food Take Out
# 51048          10457935                          Restaurant
# 56600          10482456                          Restaurant
# 66899          10526821                          Restaurant
# 73659          10564048                          Restaurant
# 74485          10568777                          Restaurant
# 79022          10602331  Food Store (Convenience / Variety)
#
#       establishment_address  inspection_id  inspection_date
# 6763       57 OSSINGTON AVE      103455536                2
# 12026     125 OSSINGTON AVE      103353246                2
# 19909        812 COLLEGE ST      103430882                2
# 24622   165 EAST LIBERTY ST      103553046                2
# 49525   3863 LAWRENCE AVE E      103029566                2
# 51048      885 PROGRESS AVE      103452615                2
# 56600        796 COLLEGE ST      103436353                2
# 66899        453 QUEEN ST W      103522898                2
# 73659     120 CUMBERLAND ST      103736038                2
# 74485          4 COLLIER ST      103769871                2
# 79022         30 DENTON AVE      104012758                2

# %% [markdown]
# These inspections wlill need to be removed from the data. The reason for this occurrence is one of the followig
# - the inspector needed to go back for a re-inspection
# - the date was incorrectly entered
# - unknown
#
# IT is reassuring that there are a small number of such inspections. Since we don't know the exact reason for this occurrence, we will remove all such inspections (that occurred on more than one day) from the data.

# %% [markdown]
# So, next, we will query this result to only get inspections that were completed on one day. We will do this using the establishment and inspection columns only, ignoring the counts and text column from earlier

# %%
# %%time
df_query_no_multi_day_inspections = df_query.groupby(
    ["establishment_id", "establishmenttype", "establishment_address", "inspection_id"],
    as_index=False,
)["inspection_date"].nunique().query("inspection_date == 1").sort_values(
    by=["inspection_date"], ascending=False
)
df_query_no_multi_day_inspections
# Out:
# CPU times: user 97.9 ms, sys: 145 µs, total: 98 ms
# Wall time: 97.2 ms
#        establishment_id          establishmenttype establishment_address  \
# 0               1222579              Food Take Out        870 MARKHAM RD
# 56699          10482577              Food Take Out       900 DUFFERIN ST
# 56697          10482559  Cafeteria - Public Access    640 LAWRENCE AVE W
# 56696          10482559  Cafeteria - Public Access    640 LAWRENCE AVE W
# 56695          10482559  Cafeteria - Public Access    640 LAWRENCE AVE W
# ...                 ...                        ...                   ...
# 28345          10327062                 Restaurant         6180 YONGE ST
# 28344          10327062                 Restaurant         6180 YONGE ST
# 28343          10327062                 Restaurant         6180 YONGE ST
# 28342          10327062                 Restaurant         6180 YONGE ST
# 85038          10690681                 Restaurant   200 QUEENS PLATE DR
#
#        inspection_id  inspection_date
# 0          103015258                1
# 56699      103218505                1
# 56697      103474423                1
# 56696      103215927                1
# 56695      103118069                1
# ...              ...              ...
# 28345      103608234                1
# 28344      103474003                1
# 28343      103347778                1
# 28342      103175034                1
# 85038      104594980                1
#
# [85028 rows x 5 columns]

# %% [markdown]
# We'll now merge this result with the aggregated data from the SQL query in order to get all columns (including text and counts) for inspections that were completed on a single date

# %%
# %%time
df = df_query_no_multi_day_inspections.drop(columns=["inspection_date"]).merge(df_query, on=["establishment_id", "establishmenttype", "establishment_address", "inspection_id"])
df["inspection_date"] = pd.to_datetime(df["inspection_date"])
df = df.sort_values(by=["establishment_id", "establishmenttype", "establishment_address", "inspection_id", "inspection_date"])
df
# Out:
# CPU times: user 114 ms, sys: 8.1 ms, total: 122 ms
# Wall time: 121 ms
#        establishment_id establishmenttype   establishment_address  \
# 0               1222579     Food Take Out          870 MARKHAM RD
# 10629           1222579     Food Take Out          870 MARKHAM RD
# 56692           1222579     Food Take Out          870 MARKHAM RD
# 56691           1222579     Food Take Out          870 MARKHAM RD
# 56690           1222579     Food Take Out          870 MARKHAM RD
# ...                 ...               ...                     ...
# 28343          10690581        Restaurant  3560 VICTORIA PARK AVE
# 28342          10690642         Bake Shop        20 ST PATRICK ST
# 28341          10690660        Restaurant          549 BLOOR ST W
# 28340          10690679     Food Take Out     1175 ST CLAIR AVE W
# 85027          10690681        Restaurant     200 QUEENS PLATE DR
#
#        inspection_id inspection_date  \
# 0          103015258      2013-06-26
# 10629      103133558      2013-12-20
# 56692      103329697      2014-09-09
# 56691      103420091      2015-01-08
# 56690      103868579      2016-12-21
# ...              ...             ...
# 28343      104594294      2019-10-22
# 28342      104594681      2019-10-23
# 28341      104594800      2019-10-23
# 28340      104594954      2019-10-23
# 85027      104594980      2019-10-23
#
#                                      infractions_summary  num_significant  \
# 0      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                4
# 10629  Food handler fail to wear headgear. Operator f...                0
# 56692  FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                3
# 56691  Operator fail to properly wash equipment. Oper...                3
# 56690           Operator fail to properly wash equipment                0
# ...                                                  ...              ...
# 28343  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 28342  FAIL TO PROVIDE THERMOMETER IN REFRIGERATION E...                1
# 28341  FAIL TO MAINTAIN HANDWASHING STATIONS (LIQUID ...                1
# 28340  SANITIZE UTENSILS IN WATER FOR LESS THAN 45 SE...                1
# 85027  Fail to Hold a Valid Food Handler's Certificat...                0
#
#        num_crucial  num_minor  num_infractions
# 0                4          8               16
# 10629            0          6                6
# 56692            0         12               15
# 56691            0          6                9
# 56690            0          1                1
# ...            ...        ...              ...
# 28343            0          3                3
# 28342            0          0                1
# 28341            0          1                2
# 28340            0          0                1
# 85027            0          0                1
#
# [85028 rows x 10 columns]

# %% [markdown]
# As a sanity check, we will now count how many `inspection_id`s and `inspection_date`s occurred for each establishment. This will give us the number of inspections per establishment. We should get the same number of inspections if we count `inspection_id` or `inspection_date`. The result of this aggregation is shown below

# %%
recomp = (
    df.groupby(
        ["establishment_id", "establishmenttype", "establishment_address"],
        as_index=False,
    )
    .agg({"inspection_id": "count", "inspection_date": "count"})
    .rename(
        columns={
            "inspection_id": "num_inspection_ids",
            "inspection_date": "num_inspection_dates",
        }
    )
)
display(recomp.head())
# Out:
#    establishment_id establishmenttype establishment_address  \
# 0           1222579     Food Take Out        870 MARKHAM RD
# 1           1222807        Restaurant   1635 LAWRENCE AVE W
# 2           9000002     Food Take Out       361 OAKWOOD AVE
# 3           9000004     Food Take Out          1788 JANE ST
# 4           9000026     Food Take Out   2372 EGLINTON AVE E
#
#    num_inspection_ids  num_inspection_dates
# 0                   9                     9
# 1                   5                     5
# 2                   1                     1
# 3                   7                     7
# 4                   8                     8

# %% [markdown]
# As we can see below, the number of inspections per establishment is equal when calculated using `inspection_id` or `inspection_date`

# %%
assert recomp[recomp["num_inspection_ids"] != recomp["num_inspection_dates"]].empty

# %% [markdown]
# We can also verify that the sum (total) of the inspections adds up to the number of rows in the aggregated data (after removing the inspections that are spread across multiple dates), and this is shown below

# %%
assert recomp["num_inspection_ids"].sum() == len(df)
assert recomp["num_inspection_dates"].sum() == len(df)

# %% [markdown]
# ### Remove Re-Inspections

# %% [markdown]
# Next, we need to eliminate inspectoins that occurred within two days since these correspond to re-inspections (as mentioned earlier). Now, a single `inspection_id` corresponds to a single `inspection_date`. Starting with the above result, we will group by establishment and calculate difference in days between successive `inspection_date`s. This will give us the time gap between successive inspections of a single establishment. This time gap needs to be more than two days to avoid including re-inspections.

# %% [markdown]
# Get the time gap between successive inspections of a single establishment

# %%
# %%time
df["days_to_next"] = (
    df.groupby(
        [
            "establishment_id",
            "establishmenttype",
            "establishment_address",
        ],
    )["inspection_date"]
    .diff(-1)
    .dt.days.abs()
)
df
# Out:
# CPU times: user 3.15 s, sys: 13.5 ms, total: 3.16 s
# Wall time: 3.12 s
#        establishment_id establishmenttype   establishment_address  \
# 0               1222579     Food Take Out          870 MARKHAM RD
# 10629           1222579     Food Take Out          870 MARKHAM RD
# 56692           1222579     Food Take Out          870 MARKHAM RD
# 56691           1222579     Food Take Out          870 MARKHAM RD
# 56690           1222579     Food Take Out          870 MARKHAM RD
# ...                 ...               ...                     ...
# 28343          10690581        Restaurant  3560 VICTORIA PARK AVE
# 28342          10690642         Bake Shop        20 ST PATRICK ST
# 28341          10690660        Restaurant          549 BLOOR ST W
# 28340          10690679     Food Take Out     1175 ST CLAIR AVE W
# 85027          10690681        Restaurant     200 QUEENS PLATE DR
#
#        inspection_id inspection_date  \
# 0          103015258      2013-06-26
# 10629      103133558      2013-12-20
# 56692      103329697      2014-09-09
# 56691      103420091      2015-01-08
# 56690      103868579      2016-12-21
# ...              ...             ...
# 28343      104594294      2019-10-22
# 28342      104594681      2019-10-23
# 28341      104594800      2019-10-23
# 28340      104594954      2019-10-23
# 85027      104594980      2019-10-23
#
#                                      infractions_summary  num_significant  \
# 0      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                4
# 10629  Food handler fail to wear headgear. Operator f...                0
# 56692  FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                3
# 56691  Operator fail to properly wash equipment. Oper...                3
# 56690           Operator fail to properly wash equipment                0
# ...                                                  ...              ...
# 28343  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 28342  FAIL TO PROVIDE THERMOMETER IN REFRIGERATION E...                1
# 28341  FAIL TO MAINTAIN HANDWASHING STATIONS (LIQUID ...                1
# 28340  SANITIZE UTENSILS IN WATER FOR LESS THAN 45 SE...                1
# 85027  Fail to Hold a Valid Food Handler's Certificat...                0
#
#        num_crucial  num_minor  num_infractions  days_to_next
# 0                4          8               16         177.0
# 10629            0          6                6         263.0
# 56692            0         12               15         121.0
# 56691            0          6                9         713.0
# 56690            0          1                1         546.0
# ...            ...        ...              ...           ...
# 28343            0          3                3           NaN
# 28342            0          0                1           NaN
# 28341            0          1                2           NaN
# 28340            0          0                1           NaN
# 85027            0          0                1           NaN
#
# [85028 rows x 11 columns]

# %% [markdown]
# Show how many establishments were re-inspected (for this, the time gap will be two days or less)

# %%
df.query("days_to_next <= 2")
# Out:
#        establishment_id establishmenttype establishment_address  \
# 56769           9000200        Restaurant         2300 YONGE ST
# 56514           9000361     Food Take Out   2847 LAWRENCE AVE E
# 56592           9000596            Bakery      3772 BATHURST ST
# 57015           9000652            Bakery       2394 BLOOR ST W
# 56864           9000963        Restaurant           33 SAMOR RD
# ...                 ...               ...                   ...
# 28115          10667988            Bakery     248 EDDYSTONE AVE
# 27994          10676175        Restaurant        688 COLLEGE ST
# 28476          10677946        Restaurant        729 BLOOR ST W
# 28472          10677946        Restaurant        729 BLOOR ST W
# 28368          10687000        Restaurant     312 ADELAIDE ST W
#
#        inspection_id inspection_date  \
# 56769      103788406      2016-08-03
# 56514      103846326      2016-11-08
# 56592      103675610      2016-02-22
# 57015      103977217      2017-05-29
# 56864      104055201      2017-11-13
# ...              ...             ...
# 28115      104452960      2019-04-16
# 27994      104502534      2019-06-20
# 28476      104517863      2019-07-15
# 28472      104571577      2019-09-23
# 28368      104568429      2019-09-18
#
#                                      infractions_summary  num_significant  \
# 56769  Operator fail to properly maintain rooms. Oper...                4
# 56514  Operator fail to properly wash equipment. Oper...               18
# 56592  Operator fail to clean washroom fixtures. Oper...                3
# 57015  Operator fail to properly maintain rooms. Stor...                0
# 56864  Operator fail to properly wash equipment. STOR...                3
# ...                                                  ...              ...
# 28115  Fail to Ensure the Presence of the Holder of a...                4
# 27994  FAIL TO PROVIDE THERMOMETER IN REFRIGERATION E...                2
# 28476  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 28472  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 28368  Food premise not maintained to permit sanitary...                1
#
#        num_crucial  num_minor  num_infractions  days_to_next
# 56769            0          8               12           2.0
# 56514            0          9               30           2.0
# 56592            0          9               12           2.0
# 57015            1          1                2           1.0
# 56864            0          3                6           0.0
# ...            ...        ...              ...           ...
# 28115            0          2                8           2.0
# 27994            2          0                4           1.0
# 28476            1          1                2           2.0
# 28472            1          3                5           1.0
# 28368            2          3                6           2.0
#
# [1326 rows x 11 columns]

# %% [markdown]
# We need to remove these re-inspections from the aggregated data from the end of the previous section.
#
# There are some establishments that might have
# - closed permanently after one inspection
# - just openend, so have only been inspected once
#
# and these appear with a missing value in the `days_to_next` column. These establishments' inspections can be kept in the data, so below we will remove re-inspections (`days_to_next` < 2) and keep establishments with a single inspection (`days_to_next` has a missing value)

# %%
df = df.query("days_to_next > 2 | days_to_next.isna()").reset_index(drop=True).copy()
df
# Out:
#        establishment_id establishmenttype   establishment_address  \
# 0               1222579     Food Take Out          870 MARKHAM RD
# 1               1222579     Food Take Out          870 MARKHAM RD
# 2               1222579     Food Take Out          870 MARKHAM RD
# 3               1222579     Food Take Out          870 MARKHAM RD
# 4               1222579     Food Take Out          870 MARKHAM RD
# ...                 ...               ...                     ...
# 83697          10690581        Restaurant  3560 VICTORIA PARK AVE
# 83698          10690642         Bake Shop        20 ST PATRICK ST
# 83699          10690660        Restaurant          549 BLOOR ST W
# 83700          10690679     Food Take Out     1175 ST CLAIR AVE W
# 83701          10690681        Restaurant     200 QUEENS PLATE DR
#
#        inspection_id inspection_date  \
# 0          103015258      2013-06-26
# 1          103133558      2013-12-20
# 2          103329697      2014-09-09
# 3          103420091      2015-01-08
# 4          103868579      2016-12-21
# ...              ...             ...
# 83697      104594294      2019-10-22
# 83698      104594681      2019-10-23
# 83699      104594800      2019-10-23
# 83700      104594954      2019-10-23
# 83701      104594980      2019-10-23
#
#                                      infractions_summary  num_significant  \
# 0      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                4
# 1      Food handler fail to wear headgear. Operator f...                0
# 2      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                3
# 3      Operator fail to properly wash equipment. Oper...                3
# 4               Operator fail to properly wash equipment                0
# ...                                                  ...              ...
# 83697  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 83698  FAIL TO PROVIDE THERMOMETER IN REFRIGERATION E...                1
# 83699  FAIL TO MAINTAIN HANDWASHING STATIONS (LIQUID ...                1
# 83700  SANITIZE UTENSILS IN WATER FOR LESS THAN 45 SE...                1
# 83701  Fail to Hold a Valid Food Handler's Certificat...                0
#
#        num_crucial  num_minor  num_infractions  days_to_next
# 0                4          8               16         177.0
# 1                0          6                6         263.0
# 2                0         12               15         121.0
# 3                0          6                9         713.0
# 4                0          1                1         546.0
# ...            ...        ...              ...           ...
# 83697            0          3                3           NaN
# 83698            0          0                1           NaN
# 83699            0          1                2           NaN
# 83700            0          0                1           NaN
# 83701            0          0                1           NaN
#
# [83702 rows x 11 columns]

# %% [markdown]
# With this, our aggregation (transformation) of the raw infractions data is completed. We now have a single row per inspection (at a single establishment on a single date).

# %% [markdown]
# ## Create the Class Labels column

# %% [markdown]
# We'll create a binary column to detect if a crucial infraction was detected or not

# %%
df["is_crucial"] = (df["num_crucial"] > 0).astype(int)
df
# Out:
#        establishment_id establishmenttype   establishment_address  \
# 0               1222579     Food Take Out          870 MARKHAM RD
# 1               1222579     Food Take Out          870 MARKHAM RD
# 2               1222579     Food Take Out          870 MARKHAM RD
# 3               1222579     Food Take Out          870 MARKHAM RD
# 4               1222579     Food Take Out          870 MARKHAM RD
# ...                 ...               ...                     ...
# 83697          10690581        Restaurant  3560 VICTORIA PARK AVE
# 83698          10690642         Bake Shop        20 ST PATRICK ST
# 83699          10690660        Restaurant          549 BLOOR ST W
# 83700          10690679     Food Take Out     1175 ST CLAIR AVE W
# 83701          10690681        Restaurant     200 QUEENS PLATE DR
#
#        inspection_id inspection_date  \
# 0          103015258      2013-06-26
# 1          103133558      2013-12-20
# 2          103329697      2014-09-09
# 3          103420091      2015-01-08
# 4          103868579      2016-12-21
# ...              ...             ...
# 83697      104594294      2019-10-22
# 83698      104594681      2019-10-23
# 83699      104594800      2019-10-23
# 83700      104594954      2019-10-23
# 83701      104594980      2019-10-23
#
#                                      infractions_summary  num_significant  \
# 0      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                4
# 1      Food handler fail to wear headgear. Operator f...                0
# 2      FAIL TO PROVIDE TOWELS IN FOOD PREPARATION ARE...                3
# 3      Operator fail to properly wash equipment. Oper...                3
# 4               Operator fail to properly wash equipment                0
# ...                                                  ...              ...
# 83697  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...                0
# 83698  FAIL TO PROVIDE THERMOMETER IN REFRIGERATION E...                1
# 83699  FAIL TO MAINTAIN HANDWASHING STATIONS (LIQUID ...                1
# 83700  SANITIZE UTENSILS IN WATER FOR LESS THAN 45 SE...                1
# 83701  Fail to Hold a Valid Food Handler's Certificat...                0
#
#        num_crucial  num_minor  num_infractions  days_to_next  is_crucial
# 0                4          8               16         177.0           1
# 1                0          6                6         263.0           0
# 2                0         12               15         121.0           0
# 3                0          6                9         713.0           0
# 4                0          1                1         546.0           0
# ...            ...        ...              ...           ...         ...
# 83697            0          3                3           NaN           0
# 83698            0          0                1           NaN           0
# 83699            0          1                2           NaN           0
# 83700            0          0                1           NaN           0
# 83701            0          0                1           NaN           0
#
# [83702 rows x 12 columns]

# %% [markdown]
# The class-imbalance is shown below (although we will not be interpreting this until we have split the data for ML experiments)

# %%
display(
    df["is_crucial"]
    .value_counts(normalize=True)
    .rename("fraction")
    .to_frame()
    .merge(
        df["is_crucial"].value_counts().rename("num_inspections").to_frame(),
        left_index=True,
        right_index=True,
        how="inner",
    )
)
# Out:
#    fraction  num_inspections
# 0  0.910767            76233
# 1  0.089233             7469

# %% [markdown]
# ## Export Transformed Data to CSV

# %% [markdown]
# We'll now export this transformed data (aggregated by inspection and filtered to remove (a) inspections that took more than one day to complete, (b) re-inspections, (c) unwanted establishment types and (d) inspections with an invalid severity) to a CSV file which can be loaded into Python for further processing

# %%
# %%time
time_now  = datetime.now().strftime('%Y%m%d_%H%M%S')
df.drop(columns=["days_to_next"]).to_csv(f"data/processed/filtered_transformed_data__{time_now}.csv", index=False)
# Out:
# CPU times: user 801 ms, sys: 7.8 ms, total: 809 ms
# Wall time: 807 ms

# %% [markdown]
# ## Disconnect from the MySQL Database

# %% [markdown]
# Close database connection and dispose the SQLAlchemy engine

# %%
conn.close()
engine.dispose()
